# %%
import pandas as pd

# %%
const = pd.read_json(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\constructors.json",lines=True)
const.head()
const.to_csv('const.csv')

# %%
const
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
drivers = pd.read_json(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\drivers.json",lines=True)
drivers.head()
#drivers.to_csv('drivers.csv')
# Out:
#    driverId   driverRef number code  \
# 0         1    hamilton     44  HAM
# 1         2    heidfeld     \N  HEI
# 2         3     rosberg      6  ROS
# 3         4      alonso     14  ALO
# 4         5  kovalainen     \N  KOV
#
#                                               name         dob nationality  \
# 0     {'forename': 'Lewis', 'surname': 'Hamilton'}  1985-01-07     British
# 1      {'forename': 'Nick', 'surname': 'Heidfeld'}  1977-05-10      German
# 2       {'forename': 'Nico', 'surname': 'Rosberg'}  1985-06-27      German
# 3    {'forename': 'Fernando', 'surname': 'Alonso'}  1981-07-29     Spanish
# 4  {'forename': 'Heikki', 'surname': 'Kovalainen'}  1981-10-19     Finnish
#
#                                               url
# 0     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3    http://en.wikipedia.org/wiki/Fernando_Alonso
# ...

# %%
drivers=pd.read_csv(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\drivers.csv") 
drivers_filter=drivers.loc[:,["driverId","driverRef","code","nationality"]]  
drivers_filter.to_csv('driversNorm.csv')
driversNorm = pd.read_csv(r'C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\driversNorm.csv')
driversNorm
# Out:
#      Unnamed: 0  driverId          driverRef code nationality
# 0             0         1           hamilton  HAM     British
# 1             1         2           heidfeld  HEI      German
# 2             2         3            rosberg  ROS      German
# 3             3         4             alonso  ALO     Spanish
# 4             4         5         kovalainen  KOV     Finnish
# ..          ...       ...                ...  ...         ...
# 848         848       850  pietro_fittipaldi  FIT   Brazilian
# 849         849       851             aitken  AIT     British
# 850         850       852            tsunoda  TSU    Japanese
# 851         851       853            mazepin  MAZ     Russian
# 852         852       854    mick_schumacher  SCH      German
#
# [853 rows x 5 columns]

# %%
results = pd.read_json(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\results.json",lines=True)
results.head()
results.to_csv('results_salida.csv')

# %%
results2=pd.read_csv(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\results_salida.csv") 
results_filter=results2.loc[:,["driverId","constructorId","raceId","positionOrder","points"]]  
results_filter.to_csv('results_filtrados.csv')
results_filtrados = pd.read_csv(r'C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\results_filtrados.csv')

# %%
results_filtrados.head()
# Out:
#    Unnamed: 0  driverId  constructorId  raceId  positionOrder  points
# 0           0         1              1      18              1    10.0
# 1           1         2              2      18              2     8.0
# 2           2         3              3      18              3     6.0
# 3           3         4              4      18              4     5.0
# 4           4         5              1      18              5     4.0

# %%
circuits = pd.read_csv(r'C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\circuits.csv')
circuits.head(20)
#circuits.drop(['url'], axis=1, inplace=True)
#circuits.to_csv('circuitsNorm.csv')
# Out:
#     circuitId      circuitRef                            name      location  \
# 0           1     albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2          sepang    Sepang International Circuit  Kuala Lumpur
# 2           3         bahrain   Bahrain International Circuit        Sakhir
# 3           4       catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4           5        istanbul                   Istanbul Park      Istanbul
# 5           6          monaco               Circuit de Monaco   Monte-Carlo
# 6           7      villeneuve       Circuit Gilles Villeneuve      Montreal
# 7           8     magny_cours   Circuit de Nevers Magny-Cours   Magny Cours
# 8           9     silverstone             Silverstone Circuit   Silverstone
# 9          10  hockenheimring                  Hockenheimring    Hockenheim
# 10         11     hungaroring                     Hungaroring      Budapest
# ...

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130

# %%
circuits=pd.read_csv(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\circuits.csv") 
circuits_filter=circuits.loc[:,["circuitId","name","location","country"]]  
circuits_filter.to_csv('circuitsNorm.csv')
circuitsNorm = pd.read_csv(r'C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\circuitsNorm.csv')
circuitsNorm
# Out:
#     Unnamed: 0  circuitId                                  name      location  \
# 0            0          1        Albert Park Grand Prix Circuit     Melbourne
# 1            1          2          Sepang International Circuit  Kuala Lumpur
# 2            2          3         Bahrain International Circuit        Sakhir
# 3            3          4        Circuit de Barcelona-Catalunya      Montmeló
# 4            4          5                         Istanbul Park      Istanbul
# ..         ...        ...                                   ...           ...
# 72          72         73                     Baku City Circuit          Baku
# 73          73         74                  Hanoi Street Circuit         Hanoi
# 74          74         75    Autódromo Internacional do Algarve      Portimão
# 75          75         76  Autodromo Internazionale del Mugello       Mugello
# 76          76         77                 Jeddah Street Circuit        Jeddah
#
#          country
# ...

# %%
races = pd.read_csv(r'C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\races.csv')
races.head(20)
# Out:
#     raceId  year  round  circuitId                   name        date  \
# 0        1  2009      1          1  Australian Grand Prix  2009-03-29
# 1        2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2        3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3        4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4        5  2009      5          4     Spanish Grand Prix  2009-05-10
# 5        6  2009      6          6      Monaco Grand Prix  2009-05-24
# 6        7  2009      7          5     Turkish Grand Prix  2009-06-07
# 7        8  2009      8          9     British Grand Prix  2009-06-21
# 8        9  2009      9         20      German Grand Prix  2009-07-12
# 9       10  2009     10         11   Hungarian Grand Prix  2009-07-26
# 10      11  2009     11         12    European Grand Prix  2009-08-23
# 11      12  2009     12         13     Belgian Grand Prix  2009-08-30
# ...

# %%
races=pd.read_csv(r"C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\Datasets\races.csv") 
races_filter=races.loc[:,["raceId","year","round","circuitId", 'name']]  
races_filter.to_csv('raceNorm.csv')
racesNorm = pd.read_csv(r'C:\Users\Santi\OneDrive\Escritorio\HENRY TPS\tp1\PI01_DATA03\raceNorm.csv')
racesNorm
# Out:
#       Unnamed: 0  raceId  year  round  circuitId                      name
# 0              0       1  2009      1          1     Australian Grand Prix
# 1              1       2  2009      2          2      Malaysian Grand Prix
# 2              2       3  2009      3         17        Chinese Grand Prix
# 3              3       4  2009      4          3        Bahrain Grand Prix
# 4              4       5  2009      5          4        Spanish Grand Prix
# ...          ...     ...   ...    ...        ...                       ...
# 1053        1053    1069  2021     18         69  United States Grand Prix
# 1054        1054    1070  2021     19         32    Mexico City Grand Prix
# 1055        1055    1071  2021     20         18      Brazilian Grand Prix
# 1056        1056    1072  2021     22         77  Saudi Arabian Grand Prix
# 1057        1057    1073  2021     23         24      Abu Dhabi Grand Prix
#
# [1058 rows x 6 columns]
